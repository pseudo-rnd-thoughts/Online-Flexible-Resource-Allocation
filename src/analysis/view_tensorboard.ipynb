# %%
# %load_ext tensorboard

# %%
import tensorflow as tf

# %%
# %tensorboard --logdir algorithms/eval_logs
# Out:
# ERROR: Timed out waiting for TensorBoard to start. It may still be running as pid 12572.
