# %%
from __future__ import annotations

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
# Load the important classes
import random as rnd
from typing import Dict, TYPE_CHECKING, List, Tuple, Optional

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np

import core.log as log
import settings.env_io as env_io
import settings.env_settings_io as env_settings_io
from agents.resource_weighting_agent import ResourceWeightingAgent
from agents.task_pricing_agent import TaskPricingAgent
from env.environment import OnlineFlexibleResourceAllocationEnv
from env.task_stage import TaskStage

if TYPE_CHECKING:
    from env.server import Server
    import numpy as np
    from env.task import Task

# %%
from train import run_env, eval_env, allocate_agents

# %%
log.console_debug_level = log.LogLevel.INFO
log.debug_filename = 'training.log'

# %%
# Setup the environment
_env = OnlineFlexibleResourceAllocationEnv.make('../settings/basic_env.json')

# %%
# Setup the agents
_task_pricing_agents = [TaskPricingAgent('Default {}'.format(agent_num)) for agent_num in range(10)]
_resource_weighting_agents = [ResourceWeightingAgent('Default {}'.format(agent_num)) for agent_num in range(10)]

# %%
# Create the training envs
_training_envs: List[str] = [f'../settings/eval_envs/eval_env_{training_env_num}.json'
                             for training_env_num in range(10)]
for training_env_num in range(10):
    _env.reset()
    env_io.save_environment(_env, f'../settings/eval_envs/eval_env_{training_env_num}.json')

# %%
episode = 0

# %%
# Loop over the episodes
episode += 1

# %%
log.info(f'Episode: {episode}')
_env.reset()

_server_task_pricing_agents, _server_resource_allocation_agents = allocate_agents(_env, _task_pricing_agents, _resource_weighting_agents)
total_price, num_completed_tasks, num_failed_tasks = run_env(_env, _server_task_pricing_agents,
                                                             _server_resource_allocation_agents)
log.info(f'Total Price: {total_price}, Num Completed Task: {num_completed_tasks}, Num Failed Tasks: {num_failed_tasks}')
# Out:
# Episode: 1
# Environment: Env State (0x1f9e7f03cc8) at time step: 0
# 	Auction Task -> Basic 107 Task (0x1f9e7f19d38) - Unassigned, Storage: 79.0, Comp: 34.0, Results data: 14.0, Auction time: 0, Deadline: 12
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []
# Unallocated tasks
# 	Basic 87 Task (0x1f9e7f1f948) - Unassigned, Storage: 56.0, Comp: 45.0, Results data: 12.0, Auction time: 1, Deadline: 13
# 	Basic 18 Task (0x1f9e7f1eaf8) - Unassigned, Storage: 68.0, Comp: 40.0, Results data: 13.0, Auction time: 3, Deadline: 12
# 	Basic 30 Task (0x1f9e7f12048) - Unassigned, Storage: 51.0, Comp: 37.0, Results data: 19.0, Auction time: 3, Deadline: 14
# 	Basic 38 Task (0x1f9e7f140d8) - Unassigned, Storage: 79.0, Comp: 31.0, Results data: 17.0, Auction time: 3, Deadline: 9
# 	Basic 49 Task (0x1f9e7f14828) - Unassigned, Storage: 56.0, Comp: 26.0, Results data: 26.0, Auction time: 3, Deadline: 13
# 	Basic 111 Task (0x1f9e7f19f78) - Unassigned, Storage: 80.0, Comp: 38.0, Results data: 12.0, Auction time: 3, Deadline: 14
# 	Basic 121 Task (0x1f9e7f21558) - Unassigned, Storage: 68.0, Comp: 48.0, Results data: 25.0, Auction time: 3, Deadline: 12
# 	Basic 106 Task (0x1f9e7f19ca8) - Unassigned, Storage: 72.0, Comp: 32.0, Results data: 15.0, Auction time: 4, Deadline: 11
# 	Basic 1 Task (0x1f9e7f1e708) - Unassigned, Storage: 57.0, Comp: 47.0, Results data: 22.0, Auction time: 5, Deadline: 11
# 	Basic 12 Task (0x1f9e7f1edc8) - Unassigned, Storage: 56.0, Comp: 58.0, Results data: 10.0, Auction time: 5, Deadline: 13
# 	Basic 2 Task (0x1f9e7f1e798) - Unassigned, Storage: 77.0, Comp: 49.0, Results data: 25.0, Auction time: 6, Deadline: 14
# 	Basic 114 Task (0x1f9e7f21168) - Unassigned, Storage: 56.0, Comp: 43.0, Results data: 28.0, Auction time: 6, Deadline: 18
# 	Basic 0 Task (0x1f9da8ff948) - Unassigned, Storage: 76.0, Comp: 43.0, Results data: 10.0, Auction time: 8, Deadline: 16
# 	Basic 78 Task (0x1f9e7f1f9d8) - Unassigned, Storage: 50.0, Comp: 51.0, Results data: 25.0, Auction time: 8, Deadline: 18
# 	Basic 101 Task (0x1f9e7f199d8) - Unassigned, Storage: 63.0, Comp: 52.0, Results data: 29.0, Auction time: 8, Deadline: 16
# 	Basic 112 Task (0x1f9e7f21048) - Unassigned, Storage: 69.0, Comp: 28.0, Results data: 29.0, Auction time: 8, Deadline: 14
# 	Basic 84 Task (0x1f9e7f1fd38) - Unassigned, Storage: 51.0, Comp: 33.0, Results data: 27.0, Auction time: 9, Deadline: 21
# 	Basic 6 Task (0x1f9e7f1e8b8) - Unassigned, Storage: 79.0, Comp: 60.0, Results data: 17.0, Auction time: 11, Deadline: 18
# 	Basic 29 Task (0x1f9e7f121f8) - Unassigned, Storage: 58.0, Comp: 25.0, Results data: 24.0, Auction time: 11, Deadline: 19
# 	Basic 56 Task (0x1f9e7f0c288) - Unassigned, Storage: 58.0, Comp: 57.0, Results data: 16.0, Auction time: 11, Deadline: 17
# 	Basic 88 Task (0x1f9e7f1f558) - Unassigned, Storage: 60.0, Comp: 36.0, Results data: 11.0, Auction time: 11, Deadline: 17
# 	Basic 119 Task (0x1f9e7f21438) - Unassigned, Storage: 54.0, Comp: 56.0, Results data: 10.0, Auction time: 11, Deadline: 21
# 	Basic 15 Task (0x1f9e7f1ed38) - Unassigned, Storage: 71.0, Comp: 44.0, Results data: 17.0, Auction time: 12, Deadline: 24
# 	Basic 31 Task (0x1f9e7f23dc8) - Unassigned, Storage: 74.0, Comp: 28.0, Results data: 24.0, Auction time: 12, Deadline: 20
# 	Basic 37 Task (0x1f9e7f14558) - Unassigned, Storage: 67.0, Comp: 60.0, Results data: 30.0, Auction time: 12, Deadline: 18
# 	Basic 85 Task (0x1f9e7f1ff78) - Unassigned, Storage: 63.0, Comp: 50.0, Results data: 14.0, Auction time: 12, Deadline: 23
# 	Basic 7 Task (0x1f9e7f1e828) - Unassigned, Storage: 78.0, Comp: 25.0, Results data: 28.0, Auction time: 14, Deadline: 23
# 	Basic 14 Task (0x1f9e7f1ee58) - Unassigned, Storage: 63.0, Comp: 30.0, Results data: 24.0, Auction time: 14, Deadline: 24
# 	Basic 68 Task (0x1f9e7f1fc18) - Unassigned, Storage: 64.0, Comp: 28.0, Results data: 26.0, Auction time: 14, Deadline: 24
# 	Basic 51 Task (0x1f9e7f0c708) - Unassigned, Storage: 71.0, Comp: 50.0, Results data: 18.0, Auction time: 15, Deadline: 26
# 	Basic 118 Task (0x1f9e7f213a8) - Unassigned, Storage: 63.0, Comp: 49.0, Results data: 25.0, Auction time: 16, Deadline: 23
# 	Basic 113 Task (0x1f9e7f210d8) - Unassigned, Storage: 62.0, Comp: 52.0, Results data: 29.0, Auction time: 17, Deadline: 25
# 	Basic 71 Task (0x1f9e7f1f3a8) - Unassigned, Storage: 50.0, Comp: 37.0, Results data: 25.0, Auction time: 18, Deadline: 24
# 	Basic 20 Task (0x1f9e7f12288) - Unassigned, Storage: 59.0, Comp: 28.0, Results data: 14.0, Auction time: 19, Deadline: 30
# 	Basic 69 Task (0x1f9e7f1fca8) - Unassigned, Storage: 78.0, Comp: 28.0, Results data: 22.0, Auction time: 19, Deadline: 29
# 	Basic 99 Task (0x1f9e7f198b8) - Unassigned, Storage: 67.0, Comp: 30.0, Results data: 28.0, Auction time: 19, Deadline: 29
# 	Basic 53 Task (0x1f9e7f0c798) - Unassigned, Storage: 59.0, Comp: 57.0, Results data: 12.0, Auction time: 20, Deadline: 30
# 	Basic 80 Task (0x1f9e7f1f4c8) - Unassigned, Storage: 58.0, Comp: 29.0, Results data: 23.0, Auction time: 20, Deadline: 30
# 	Basic 90 Task (0x1f9e7f16168) - Unassigned, Storage: 62.0, Comp: 54.0, Results data: 18.0, Auction time: 20, Deadline: 32
# 	Basic 104 Task (0x1f9e7f19b88) - Unassigned, Storage: 69.0, Comp: 48.0, Results data: 10.0, Auction time: 20, Deadline: 30
# 	Basic 91 Task (0x1f9e7f161f8) - Unassigned, Storage: 64.0, Comp: 33.0, Results data: 16.0, Auction time: 21, Deadline: 27
# 	Basic 115 Task (0x1f9e7f211f8) - Unassigned, Storage: 69.0, Comp: 30.0, Results data: 19.0, Auction time: 21, Deadline: 29
# 	Basic 35 Task (0x1f9e7f14168) - Unassigned, Storage: 79.0, Comp: 38.0, Results data: 30.0, Auction time: 22, Deadline: 34
# 	Basic 60 Task (0x1f9e7f0c828) - Unassigned, Storage: 61.0, Comp: 58.0, Results data: 13.0, Auction time: 22, Deadline: 29
# 	Basic 61 Task (0x1f9e7f0c1f8) - Unassigned, Storage: 51.0, Comp: 35.0, Results data: 25.0, Auction time: 23, Deadline: 33
# 	Basic 96 Task (0x1f9e7f19558) - Unassigned, Storage: 80.0, Comp: 26.0, Results data: 28.0, Auction time: 23, Deadline: 32
# 	Basic 28 Task (0x1f9e7f12558) - Unassigned, Storage: 58.0, Comp: 56.0, Results data: 22.0, Auction time: 24, Deadline: 31
# 	Basic 39 Task (0x1f9e7f14048) - Unassigned, Storage: 63.0, Comp: 34.0, Results data: 21.0, Auction time: 24, Deadline: 31
# 	Basic 8 Task (0x1f9e7f1e9d8) - Unassigned, Storage: 66.0, Comp: 54.0, Results data: 15.0, Auction time: 25, Deadline: 32
# 	Basic 73 Task (0x1f9e7f1f678) - Unassigned, Storage: 50.0, Comp: 56.0, Results data: 23.0, Auction time: 25, Deadline: 35
# 	Basic 54 Task (0x1f9e7f0c4c8) - Unassigned, Storage: 51.0, Comp: 46.0, Results data: 24.0, Auction time: 26, Deadline: 33
# 	Basic 58 Task (0x1f9e7f0c048) - Unassigned, Storage: 50.0, Comp: 60.0, Results data: 12.0, Auction time: 26, Deadline: 38
# 	Basic 75 Task (0x1f9e7f1f318) - Unassigned, Storage: 80.0, Comp: 41.0, Results data: 11.0, Auction time: 26, Deadline: 37
# 	Basic 13 Task (0x1f9e7f1ea68) - Unassigned, Storage: 72.0, Comp: 51.0, Results data: 22.0, Auction time: 27, Deadline: 38
# 	Basic 76 Task (0x1f9e7f1f828) - Unassigned, Storage: 54.0, Comp: 30.0, Results data: 25.0, Auction time: 28, Deadline: 38
# 	Basic 109 Task (0x1f9e7f19e58) - Unassigned, Storage: 57.0, Comp: 42.0, Results data: 27.0, Auction time: 28, Deadline: 36
# 	Basic 16 Task (0x1f9e7f1e948) - Unassigned, Storage: 64.0, Comp: 39.0, Results data: 29.0, Auction time: 29, Deadline: 37
# 	Basic 47 Task (0x1f9e7f14318) - Unassigned, Storage: 72.0, Comp: 26.0, Results data: 14.0, Auction time: 29, Deadline: 36
# 	Basic 17 Task (0x1f9e7f1ec18) - Unassigned, Storage: 53.0, Comp: 32.0, Results data: 22.0, Auction time: 30, Deadline: 39
# 	Basic 82 Task (0x1f9e7f1f438) - Unassigned, Storage: 76.0, Comp: 31.0, Results data: 19.0, Auction time: 31, Deadline: 39
# 	Basic 95 Task (0x1f9e7f195e8) - Unassigned, Storage: 51.0, Comp: 26.0, Results data: 16.0, Auction time: 31, Deadline: 41
# 	Basic 3 Task (0x1f9e7f1ef78) - Unassigned, Storage: 71.0, Comp: 35.0, Results data: 25.0, Auction time: 32, Deadline: 38
# 	Basic 57 Task (0x1f9e7f0c5e8) - Unassigned, Storage: 62.0, Comp: 57.0, Results data: 24.0, Auction time: 32, Deadline: 43
# 	Basic 94 Task (0x1f9e7f16288) - Unassigned, Storage: 73.0, Comp: 33.0, Results data: 25.0, Auction time: 32, Deadline: 39
# 	Basic 33 Task (0x1f9e7f23ee8) - Unassigned, Storage: 76.0, Comp: 43.0, Results data: 11.0, Auction time: 33, Deadline: 41
# 	Basic 62 Task (0x1f9e7f0c3a8) - Unassigned, Storage: 62.0, Comp: 25.0, Results data: 28.0, Auction time: 33, Deadline: 44
# 	Basic 63 Task (0x1f9e7f0c438) - Unassigned, Storage: 54.0, Comp: 32.0, Results data: 15.0, Auction time: 33, Deadline: 43
# 	Basic 70 Task (0x1f9e7f1fb88) - Unassigned, Storage: 55.0, Comp: 46.0, Results data: 21.0, Auction time: 33, Deadline: 42
# 	Basic 65 Task (0x1f9e7f0c8b8) - Unassigned, Storage: 75.0, Comp: 35.0, Results data: 14.0, Auction time: 34, Deadline: 40
# 	Basic 40 Task (0x1f9e7f141f8) - Unassigned, Storage: 61.0, Comp: 25.0, Results data: 19.0, Auction time: 35, Deadline: 47
# 	Basic 45 Task (0x1f9e7f14438) - Unassigned, Storage: 55.0, Comp: 50.0, Results data: 21.0, Auction time: 35, Deadline: 47
# 	Basic 4 Task (0x1f9e7f1e678) - Unassigned, Storage: 72.0, Comp: 43.0, Results data: 28.0, Auction time: 36, Deadline: 45
# 	Basic 83 Task (0x1f9e7f1f8b8) - Unassigned, Storage: 80.0, Comp: 59.0, Results data: 25.0, Auction time: 36, Deadline: 47
# 	Basic 89 Task (0x1f9e7f1faf8) - Unassigned, Storage: 64.0, Comp: 51.0, Results data: 25.0, Auction time: 36, Deadline: 48
# 	Basic 32 Task (0x1f9e7f23f78) - Unassigned, Storage: 58.0, Comp: 32.0, Results data: 26.0, Auction time: 37, Deadline: 45
# 	Basic 97 Task (0x1f9e7f19798) - Unassigned, Storage: 68.0, Comp: 25.0, Results data: 18.0, Auction time: 37, Deadline: 45
# 	Basic 100 Task (0x1f9e7f19948) - Unassigned, Storage: 65.0, Comp: 25.0, Results data: 25.0, Auction time: 37, Deadline: 44
# 	Basic 116 Task (0x1f9e7f21288) - Unassigned, Storage: 65.0, Comp: 54.0, Results data: 17.0, Auction time: 37, Deadline: 45
# 	Basic 5 Task (0x1f9e7f1eee8) - Unassigned, Storage: 62.0, Comp: 50.0, Results data: 19.0, Auction time: 38, Deadline: 48
# 	Basic 10 Task (0x1f9e7f1eca8) - Unassigned, Storage: 66.0, Comp: 45.0, Results data: 15.0, Auction time: 41, Deadline: 48
# 	Basic 59 Task (0x1f9e7f0c168) - Unassigned, Storage: 71.0, Comp: 54.0, Results data: 30.0, Auction time: 41, Deadline: 47
# 	Basic 79 Task (0x1f9e7f1f798) - Unassigned, Storage: 52.0, Comp: 35.0, Results data: 30.0, Auction time: 41, Deadline: 51
# 	Basic 9 Task (0x1f9e7f1eb88) - Unassigned, Storage: 53.0, Comp: 27.0, Results data: 30.0, Auction time: 42, Deadline: 52
# 	Basic 105 Task (0x1f9e7f19c18) - Unassigned, Storage: 60.0, Comp: 57.0, Results data: 29.0, Auction time: 42, Deadline: 50
# 	Basic 52 Task (0x1f9e7f0c318) - Unassigned, Storage: 65.0, Comp: 58.0, Results data: 15.0, Auction time: 43, Deadline: 55
# 	Basic 103 Task (0x1f9e7f19af8) - Unassigned, Storage: 74.0, Comp: 44.0, Results data: 17.0, Auction time: 43, Deadline: 51
# 	Basic 122 Task (0x1f9e7f215e8) - Unassigned, Storage: 78.0, Comp: 42.0, Results data: 17.0, Auction time: 43, Deadline: 53
# 	Basic 19 Task (0x1f9e7f124c8) - Unassigned, Storage: 56.0, Comp: 27.0, Results data: 17.0, Auction time: 44, Deadline: 55
# 	Basic 24 Task (0x1f9e7f123a8) - Unassigned, Storage: 73.0, Comp: 57.0, Results data: 28.0, Auction time: 44, Deadline: 52
# 	Basic 117 Task (0x1f9e7f21318) - Unassigned, Storage: 59.0, Comp: 44.0, Results data: 28.0, Auction time: 44, Deadline: 51
# 	Basic 123 Task (0x1f9e7f21678) - Unassigned, Storage: 64.0, Comp: 59.0, Results data: 25.0, Auction time: 44, Deadline: 54
# 	Basic 64 Task (0x1f9e7f0c558) - Unassigned, Storage: 56.0, Comp: 55.0, Results data: 10.0, Auction time: 45, Deadline: 51
# 	Basic 67 Task (0x1f9e7f1fdc8) - Unassigned, Storage: 59.0, Comp: 27.0, Results data: 29.0, Auction time: 45, Deadline: 55
# 	Basic 23 Task (0x1f9e7f12318) - Unassigned, Storage: 55.0, Comp: 45.0, Results data: 21.0, Auction time: 47, Deadline: 55
# 	Basic 26 Task (0x1f9e7f12438) - Unassigned, Storage: 76.0, Comp: 26.0, Results data: 29.0, Auction time: 47, Deadline: 56
# 	Basic 44 Task (0x1f9e7f14798) - Unassigned, Storage: 51.0, Comp: 57.0, Results data: 26.0, Auction time: 47, Deadline: 59
# 	Basic 48 Task (0x1f9e7f145e8) - Unassigned, Storage: 76.0, Comp: 27.0, Results data: 13.0, Auction time: 48, Deadline: 55
# 	Basic 72 Task (0x1f9e7f1f708) - Unassigned, Storage: 66.0, Comp: 33.0, Results data: 29.0, Auction time: 48, Deadline: 54
# 	Basic 92 Task (0x1f9e7f16048) - Unassigned, Storage: 75.0, Comp: 33.0, Results data: 20.0, Auction time: 48, Deadline: 60
# 	Basic 43 Task (0x1f9e7f14708) - Unassigned, Storage: 80.0, Comp: 45.0, Results data: 18.0, Auction time: 49, Deadline: 61
# 	Basic 81 Task (0x1f9e7f1f288) - Unassigned, Storage: 60.0, Comp: 54.0, Results data: 21.0, Auction time: 49, Deadline: 59
# 	Basic 98 Task (0x1f9e7f19828) - Unassigned, Storage: 61.0, Comp: 32.0, Results data: 14.0, Auction time: 49, Deadline: 55
# 	Basic 22 Task (0x1f9e7f120d8) - Unassigned, Storage: 54.0, Comp: 52.0, Results data: 23.0, Auction time: 50, Deadline: 59
# 	Basic 25 Task (0x1f9e7f12678) - Unassigned, Storage: 65.0, Comp: 33.0, Results data: 25.0, Auction time: 50, Deadline: 58
# 	Basic 50 Task (0x1f9e7f0c678) - Unassigned, Storage: 73.0, Comp: 43.0, Results data: 12.0, Auction time: 50, Deadline: 62
# 	Basic 108 Task (0x1f9e7f19dc8) - Unassigned, Storage: 67.0, Comp: 35.0, Results data: 16.0, Auction time: 50, Deadline: 61
# 	Basic 42 Task (0x1f9e7f14678) - Unassigned, Storage: 68.0, Comp: 55.0, Results data: 10.0, Auction time: 52, Deadline: 58
# 	Basic 66 Task (0x1f9e7f1f5e8) - Unassigned, Storage: 80.0, Comp: 39.0, Results data: 13.0, Auction time: 52, Deadline: 59
# 	Basic 93 Task (0x1f9e7f160d8) - Unassigned, Storage: 62.0, Comp: 57.0, Results data: 13.0, Auction time: 53, Deadline: 65
# 	Basic 21 Task (0x1f9e7f125e8) - Unassigned, Storage: 64.0, Comp: 41.0, Results data: 17.0, Auction time: 54, Deadline: 63
# 	Basic 34 Task (0x1f9e7f23e58) - Unassigned, Storage: 69.0, Comp: 47.0, Results data: 24.0, Auction time: 54, Deadline: 66
# 	Basic 55 Task (0x1f9e7f0c0d8) - Unassigned, Storage: 71.0, Comp: 31.0, Results data: 12.0, Auction time: 54, Deadline: 63
# 	Basic 110 Task (0x1f9e7f19ee8) - Unassigned, Storage: 76.0, Comp: 29.0, Results data: 24.0, Auction time: 54, Deadline: 61
# 	Basic 86 Task (0x1f9e7f1fa68) - Unassigned, Storage: 66.0, Comp: 51.0, Results data: 25.0, Auction time: 55, Deadline: 66
# 	Basic 11 Task (0x1f9e7f1e5e8) - Unassigned, Storage: 73.0, Comp: 28.0, Results data: 27.0, Auction time: 56, Deadline: 66
# 	Basic 36 Task (0x1f9e7f143a8) - Unassigned, Storage: 72.0, Comp: 40.0, Results data: 28.0, Auction time: 56, Deadline: 64
# 	Basic 41 Task (0x1f9e7f14288) - Unassigned, Storage: 61.0, Comp: 52.0, Results data: 20.0, Auction time: 56, Deadline: 63
# 	Basic 46 Task (0x1f9e7f144c8) - Unassigned, Storage: 74.0, Comp: 30.0, Results data: 28.0, Auction time: 56, Deadline: 68
# 	Basic 77 Task (0x1f9e7f1fee8) - Unassigned, Storage: 58.0, Comp: 35.0, Results data: 30.0, Auction time: 56, Deadline: 64
# 	Basic 120 Task (0x1f9e7f214c8) - Unassigned, Storage: 56.0, Comp: 47.0, Results data: 16.0, Auction time: 56, Deadline: 65
# 	Basic 27 Task (0x1f9e7f12168) - Unassigned, Storage: 78.0, Comp: 60.0, Results data: 11.0, Auction time: 57, Deadline: 67
# 	Basic 74 Task (0x1f9e7f1fe58) - Unassigned, Storage: 62.0, Comp: 52.0, Results data: 24.0, Auction time: 58, Deadline: 64
# 	Basic 102 Task (0x1f9e7f19a68) - Unassigned, Storage: 53.0, Comp: 36.0, Results data: 26.0, Auction time: 59, Deadline: 70
#
# Task Pricing agents - {Basic 0 Server: Default 1, Basic 1 Server: Default 3, Basic 2 Server: Default 1, Basic 3 Server: Default 2, Basic 4 Server: Default 0, Basic 5 Server: Default 9}
# Resource allocation agents - {Basic 0 Server: Default 6, Basic 1 Server: Default 2, Basic 2 Server: Default 8, Basic 3 Server: Default 7, Basic 4 Server: Default 5, Basic 5 Server: Default 8}
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 10, Basic 2 Server: 7, Basic 3 Server: 2, Basic 4 Server: 9, Basic 5 Server: 5}
# Auction Rewards - {Basic 3 Server: 2}
# Next State: Env State (0x1f9e7f03ea8) at time step: 0
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107], Basic 4: [], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [], Basic 2 Server: [], Basic 3 Server: [Basic 107 Task: 1.0], Basic 4 Server: [], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 3: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 1
# 	Auction Task -> Basic 87 Task (0x1f9e7f1f948) - Unassigned, Storage: 56.0, Comp: 45.0, Results data: 12.0, Auction time: 1, Deadline: 13
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107], Basic 4: [], Basic 5: []
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 9, Basic 2 Server: 8, Basic 3 Server: 4, Basic 4 Server: 6, Basic 5 Server: 10}
# Auction Rewards - {Basic 3 Server: 4}
# Next State: Env State (0x1f9e7f03ea8) at time step: 1
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87], Basic 4: [], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [], Basic 2 Server: [], Basic 3 Server: [Basic 107 Task: 3, Basic 87 Task: 9], Basic 4 Server: [], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 3: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 2
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87], Basic 4: [], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [], Basic 2 Server: [], Basic 3 Server: [Basic 107 Task: 1, Basic 87 Task: 4], Basic 4 Server: [], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 3: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 3
# 	Auction Task -> Basic 18 Task (0x1f9e7f1eaf8) - Unassigned, Storage: 68.0, Comp: 40.0, Results data: 13.0, Auction time: 3, Deadline: 12
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87], Basic 4: [], Basic 5: []
#
# Auction prices - {Basic 0 Server: 10, Basic 1 Server: 9, Basic 2 Server: 5, Basic 3 Server: 8, Basic 4 Server: 6, Basic 5 Server: 4}
# Auction Rewards - {Basic 5 Server: 4}
# Next State: Env State (0x1f9e7f03cc8) at time step: 3
# 	Auction Task -> Basic 30 Task (0x1f9e7f12048) - Unassigned, Storage: 51.0, Comp: 37.0, Results data: 19.0, Auction time: 3, Deadline: 14
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87], Basic 4: [], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 9, Basic 1 Server: 6, Basic 2 Server: 10, Basic 3 Server: 6, Basic 4 Server: 0, Basic 5 Server: 6}
# Auction Rewards - {Basic 3 Server: 6}
# Next State: Env State (0x1f9e7f03ea8) at time step: 3
# 	Auction Task -> Basic 38 Task (0x1f9e7f140d8) - Unassigned, Storage: 79.0, Comp: 31.0, Results data: 17.0, Auction time: 3, Deadline: 9
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 7, Basic 2 Server: 9, Basic 3 Server: 3, Basic 4 Server: 8, Basic 5 Server: 1}
# Auction Rewards - {Basic 5 Server: 1}
# Next State: Env State (0x1f9e7f03cc8) at time step: 3
# 	Auction Task -> Basic 49 Task (0x1f9e7f14828) - Unassigned, Storage: 56.0, Comp: 26.0, Results data: 26.0, Auction time: 3, Deadline: 13
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [], Basic 5: [Basic 18, Basic 38]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 6, Basic 2 Server: 0, Basic 3 Server: 2, Basic 4 Server: 1, Basic 5 Server: 7}
# Auction Rewards - {Basic 4 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 3
# 	Auction Task -> Basic 111 Task (0x1f9e7f19f78) - Unassigned, Storage: 80.0, Comp: 38.0, Results data: 12.0, Auction time: 3, Deadline: 14
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 1, Basic 2 Server: 1, Basic 3 Server: 0, Basic 4 Server: 4, Basic 5 Server: 9}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e7f03cc8) at time step: 3
# 	Auction Task -> Basic 121 Task (0x1f9e7f21558) - Unassigned, Storage: 68.0, Comp: 48.0, Results data: 25.0, Auction time: 3, Deadline: 12
# 	Servers -> Basic 0: [], Basic 1: [], Basic 2: [Basic 111], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38]
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 10, Basic 2 Server: 7, Basic 3 Server: 7, Basic 4 Server: 9, Basic 5 Server: 0}
# Auction Rewards - {Basic 0 Server: 2}
# Next State: Env State (0x1f9e7f03ea8) at time step: 3
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1.0], Basic 1 Server: [], Basic 2 Server: [Basic 111 Task: 1.0], Basic 3 Server: [Basic 107 Task: 1, Basic 87 Task: 6, Basic 30 Task: 6], Basic 4 Server: [Basic 49 Task: 1.0], Basic 5 Server: [Basic 18 Task: 7, Basic 38 Task: 8]}
# Resource allocation Rewards - {Basic 0: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 4
# 	Auction Task -> Basic 106 Task (0x1f9e7f19ca8) - Unassigned, Storage: 72.0, Comp: 32.0, Results data: 15.0, Auction time: 4, Deadline: 11
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 6, Basic 2 Server: 7, Basic 3 Server: 0, Basic 4 Server: 7, Basic 5 Server: 3}
# Auction Rewards - {Basic 5 Server: 3}
# Next State: Env State (0x1f9e7f03ea8) at time step: 4
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1.0], Basic 1 Server: [], Basic 2 Server: [Basic 111 Task: 1.0], Basic 3 Server: [Basic 107 Task: 1, Basic 87 Task: 8, Basic 30 Task: 4], Basic 4 Server: [Basic 49 Task: 1.0], Basic 5 Server: [Basic 18 Task: 1, Basic 38 Task: 9, Basic 106 Task: 8]}
# Resource allocation Rewards - {Basic 0: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 5
# 	Auction Task -> Basic 1 Task (0x1f9e7f1e708) - Unassigned, Storage: 57.0, Comp: 47.0, Results data: 22.0, Auction time: 5, Deadline: 11
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 9, Basic 2 Server: 1, Basic 3 Server: 7, Basic 4 Server: 1, Basic 5 Server: 4}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 5
# 	Auction Task -> Basic 12 Task (0x1f9e7f1edc8) - Unassigned, Storage: 56.0, Comp: 58.0, Results data: 10.0, Auction time: 5, Deadline: 13
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 9, Basic 1 Server: 6, Basic 2 Server: 0, Basic 3 Server: 0, Basic 4 Server: 5, Basic 5 Server: 7}
# Auction Rewards - {Basic 4 Server: 5}
# Next State: Env State (0x1f9e7f03cc8) at time step: 5
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1.0], Basic 1 Server: [], Basic 2 Server: [Basic 111 Task: 6, Basic 1 Task: 1], Basic 3 Server: [Basic 107 Task: 8, Basic 87 Task: 1, Basic 30 Task: 1], Basic 4 Server: [Basic 49 Task: 10, Basic 12 Task: 6], Basic 5 Server: [Basic 18 Task: 7, Basic 38 Task: 9, Basic 106 Task: 8]}
# Resource allocation Rewards - {Basic 0: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 6
# 	Auction Task -> Basic 2 Task (0x1f9e7f1e798) - Unassigned, Storage: 77.0, Comp: 49.0, Results data: 25.0, Auction time: 6, Deadline: 14
# 	Servers -> Basic 0: [Basic 121], Basic 1: [], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 1, Basic 2 Server: 9, Basic 3 Server: 0, Basic 4 Server: 3, Basic 5 Server: 6}
# Auction Rewards - {Basic 1 Server: 1}
# Next State: Env State (0x1f9e7f03cc8) at time step: 6
# 	Auction Task -> Basic 114 Task (0x1f9e7f21168) - Unassigned, Storage: 56.0, Comp: 43.0, Results data: 28.0, Auction time: 6, Deadline: 18
# 	Servers -> Basic 0: [Basic 121], Basic 1: [Basic 2], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 1, Basic 2 Server: 6, Basic 3 Server: 10, Basic 4 Server: 7, Basic 5 Server: 2}
# Auction Rewards - {Basic 1 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 6
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1.0], Basic 1 Server: [Basic 2 Task: 10, Basic 114 Task: 10], Basic 2 Server: [Basic 111 Task: 3, Basic 1 Task: 9], Basic 3 Server: [Basic 107 Task: 10, Basic 87 Task: 3, Basic 30 Task: 5], Basic 4 Server: [Basic 49 Task: 3, Basic 12 Task: 7], Basic 5 Server: [Basic 18 Task: 2, Basic 38 Task: 6, Basic 106 Task: 10]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 7
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1.0], Basic 1 Server: [Basic 2 Task: 3, Basic 114 Task: 10], Basic 2 Server: [Basic 111 Task: 10, Basic 1 Task: 3], Basic 3 Server: [Basic 107 Task: 1, Basic 87 Task: 8, Basic 30 Task: 7], Basic 4 Server: [Basic 49 Task: 10, Basic 12 Task: 3], Basic 5 Server: [Basic 18 Task: 4, Basic 38 Task: 4, Basic 106 Task: 10]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 8
# 	Auction Task -> Basic 0 Task (0x1f9da8ff948) - Unassigned, Storage: 76.0, Comp: 43.0, Results data: 10.0, Auction time: 8, Deadline: 16
# 	Servers -> Basic 0: [Basic 121], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 9, Basic 2 Server: 9, Basic 3 Server: 0, Basic 4 Server: 7, Basic 5 Server: 8}
# Auction Rewards - {Basic 0 Server: 6}
# Next State: Env State (0x1f9e7f03cc8) at time step: 8
# 	Auction Task -> Basic 78 Task (0x1f9e7f1f9d8) - Unassigned, Storage: 50.0, Comp: 51.0, Results data: 25.0, Auction time: 8, Deadline: 18
# 	Servers -> Basic 0: [Basic 121, Basic 0], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 0, Basic 1 Server: 0, Basic 2 Server: 3, Basic 3 Server: 10, Basic 4 Server: 10, Basic 5 Server: 6}
# Auction Rewards - {Basic 2 Server: 3}
# Next State: Env State (0x1f9e7f03ea8) at time step: 8
# 	Auction Task -> Basic 101 Task (0x1f9e7f199d8) - Unassigned, Storage: 63.0, Comp: 52.0, Results data: 29.0, Auction time: 8, Deadline: 16
# 	Servers -> Basic 0: [Basic 121, Basic 0], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 7, Basic 2 Server: 7, Basic 3 Server: 5, Basic 4 Server: 10, Basic 5 Server: 0}
# Auction Rewards - {Basic 0 Server: 4}
# Next State: Env State (0x1f9e7f03cc8) at time step: 8
# 	Auction Task -> Basic 112 Task (0x1f9e7f21048) - Unassigned, Storage: 69.0, Comp: 28.0, Results data: 29.0, Auction time: 8, Deadline: 14
# 	Servers -> Basic 0: [Basic 121, Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 2, Basic 2 Server: 5, Basic 3 Server: 10, Basic 4 Server: 1, Basic 5 Server: 2}
# Auction Rewards - {Basic 4 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 8
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121, Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 107, Basic 87, Basic 30], Basic 4: [Basic 49, Basic 12, Basic 112], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 4, Basic 0 Task: 1, Basic 101 Task: 1], Basic 1 Server: [Basic 2 Task: 5, Basic 114 Task: 5], Basic 2 Server: [Basic 111 Task: 9, Basic 1 Task: 5, Basic 78 Task: 8], Basic 3 Server: [Basic 107 Task: 7, Basic 87 Task: 7, Basic 30 Task: 1], Basic 4 Server: [Basic 49 Task: 2, Basic 12 Task: 7, Basic 112 Task: 10], Basic 5 Server: [Basic 18 Task: 10, Basic 38 Task: 5, Basic 106 Task: 3]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 9
# 	Auction Task -> Basic 84 Task (0x1f9e7f1fd38) - Unassigned, Storage: 51.0, Comp: 33.0, Results data: 27.0, Auction time: 9, Deadline: 21
# 	Servers -> Basic 0: [Basic 121, Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 49, Basic 12, Basic 112], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 2, Basic 2 Server: 6, Basic 3 Server: 8, Basic 4 Server: 2, Basic 5 Server: 0}
# Auction Rewards - {Basic 4 Server: 2}
# Next State: Env State (0x1f9e7f03ea8) at time step: 9
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121, Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 49, Basic 12, Basic 112, Basic 84], Basic 5: [Basic 18, Basic 38, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 1, Basic 0 Task: 7, Basic 101 Task: 1], Basic 1 Server: [Basic 2 Task: 10, Basic 114 Task: 2], Basic 2 Server: [Basic 111 Task: 2, Basic 1 Task: 9, Basic 78 Task: 10], Basic 3 Server: [Basic 87 Task: 7, Basic 107 Task: 8, Basic 30 Task: 4], Basic 4 Server: [Basic 49 Task: 8, Basic 12 Task: 3, Basic 112 Task: 4, Basic 84 Task: 10], Basic 5 Server: [Basic 18 Task: 7, Basic 38 Task: 2, Basic 106 Task: 7]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: [Basic 38]}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 10
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 121, Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 111, Basic 1, Basic 78], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 49, Basic 12, Basic 112, Basic 84], Basic 5: [Basic 18, Basic 106]
#
# Resource allocation weights - {Basic 0 Server: [Basic 121 Task: 4, Basic 0 Task: 5, Basic 101 Task: 5], Basic 1 Server: [Basic 2 Task: 2, Basic 114 Task: 4], Basic 2 Server: [Basic 111 Task: 8, Basic 1 Task: 2, Basic 78 Task: 6], Basic 3 Server: [Basic 87 Task: 9, Basic 107 Task: 4, Basic 30 Task: 6], Basic 4 Server: [Basic 49 Task: 3, Basic 12 Task: 1, Basic 112 Task: 9, Basic 84 Task: 7], Basic 5 Server: [Basic 18 Task: 3, Basic 106 Task: 4]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [Basic 111], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 11
# 	Auction Task -> Basic 6 Task (0x1f9e7f1e8b8) - Unassigned, Storage: 79.0, Comp: 60.0, Results data: 17.0, Auction time: 11, Deadline: 18
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114], Basic 2: [Basic 1, Basic 78], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49], Basic 5: [Basic 18, Basic 106]
#
# Auction prices - {Basic 0 Server: 3, Basic 1 Server: 2, Basic 2 Server: 4, Basic 3 Server: 0, Basic 4 Server: 0, Basic 5 Server: 3}
# Auction Rewards - {Basic 1 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 11
# 	Auction Task -> Basic 29 Task (0x1f9e7f121f8) - Unassigned, Storage: 58.0, Comp: 25.0, Results data: 24.0, Auction time: 11, Deadline: 19
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 1, Basic 78], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49], Basic 5: [Basic 18, Basic 106]
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 2, Basic 2 Server: 1, Basic 3 Server: 7, Basic 4 Server: 10, Basic 5 Server: 8}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 11
# 	Auction Task -> Basic 56 Task (0x1f9e7f0c288) - Unassigned, Storage: 58.0, Comp: 57.0, Results data: 16.0, Auction time: 11, Deadline: 17
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 1, Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49], Basic 5: [Basic 18, Basic 106]
#
# Auction prices - {Basic 0 Server: 10, Basic 1 Server: 2, Basic 2 Server: 4, Basic 3 Server: 2, Basic 4 Server: 6, Basic 5 Server: 3}
# Auction Rewards - {Basic 3 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 11
# 	Auction Task -> Basic 88 Task (0x1f9e7f1f558) - Unassigned, Storage: 60.0, Comp: 36.0, Results data: 11.0, Auction time: 11, Deadline: 17
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 1, Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49], Basic 5: [Basic 18, Basic 106]
#
# Auction prices - {Basic 0 Server: 9, Basic 1 Server: 8, Basic 2 Server: 9, Basic 3 Server: 6, Basic 4 Server: 5, Basic 5 Server: 8}
# Auction Rewards - {Basic 4 Server: 5}
# Next State: Env State (0x1f9e7f03ea8) at time step: 11
# 	Auction Task -> Basic 119 Task (0x1f9e7f21438) - Unassigned, Storage: 54.0, Comp: 56.0, Results data: 10.0, Auction time: 11, Deadline: 21
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 1, Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49, Basic 88], Basic 5: [Basic 18, Basic 106]
#
# Auction prices - {Basic 0 Server: 0, Basic 1 Server: 7, Basic 2 Server: 9, Basic 3 Server: 2, Basic 4 Server: 2, Basic 5 Server: 6}
# Auction Rewards - {Basic 3 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 11
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 1, Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 49, Basic 88], Basic 5: [Basic 18, Basic 106]
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 6, Basic 101 Task: 7, Basic 121 Task: 8], Basic 1 Server: [Basic 2 Task: 9, Basic 114 Task: 1, Basic 6 Task: 10], Basic 2 Server: [Basic 1 Task: 8, Basic 78 Task: 8, Basic 29 Task: 7], Basic 3 Server: [Basic 87 Task: 7, Basic 107 Task: 3, Basic 30 Task: 8, Basic 56 Task: 8, Basic 119 Task: 10], Basic 4 Server: [Basic 12 Task: 9, Basic 112 Task: 9, Basic 84 Task: 6, Basic 49 Task: 10, Basic 88 Task: 1], Basic 5 Server: [Basic 18 Task: 10, Basic 106 Task: 5]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [Basic 1], Basic 3: [], Basic 4: [], Basic 5: [Basic 106]}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 12
# 	Auction Task -> Basic 15 Task (0x1f9e7f1ed38) - Unassigned, Storage: 71.0, Comp: 44.0, Results data: 17.0, Auction time: 12, Deadline: 24
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 3, Basic 2 Server: 6, Basic 3 Server: 2, Basic 4 Server: 9, Basic 5 Server: 6}
# Auction Rewards - {Basic 3 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 12
# 	Auction Task -> Basic 31 Task (0x1f9e7f23dc8) - Unassigned, Storage: 74.0, Comp: 28.0, Results data: 24.0, Auction time: 12, Deadline: 20
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119, Basic 15], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 0, Basic 2 Server: 2, Basic 3 Server: 3, Basic 4 Server: 10, Basic 5 Server: 2}
# Auction Rewards - {Basic 2 Server: 2}
# Next State: Env State (0x1f9e7f03ea8) at time step: 12
# 	Auction Task -> Basic 37 Task (0x1f9e7f14558) - Unassigned, Storage: 67.0, Comp: 60.0, Results data: 30.0, Auction time: 12, Deadline: 18
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29, Basic 31], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119, Basic 15], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 5, Basic 2 Server: 10, Basic 3 Server: 1, Basic 4 Server: 10, Basic 5 Server: 4}
# Auction Rewards - {Basic 3 Server: 1}
# Next State: Env State (0x1f9e7f03cc8) at time step: 12
# 	Auction Task -> Basic 85 Task (0x1f9e7f1ff78) - Unassigned, Storage: 63.0, Comp: 50.0, Results data: 14.0, Auction time: 12, Deadline: 23
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29, Basic 31], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: [Basic 18]
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 7, Basic 2 Server: 1, Basic 3 Server: 6, Basic 4 Server: 7, Basic 5 Server: 6}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 12
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 121], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 87, Basic 107, Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: [Basic 18]
#
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 4, Basic 101 Task: 2, Basic 121 Task: 1], Basic 1 Server: [Basic 2 Task: 5, Basic 114 Task: 5, Basic 6 Task: 8], Basic 2 Server: [Basic 78 Task: 10, Basic 29 Task: 3, Basic 31 Task: 1, Basic 85 Task: 7], Basic 3 Server: [Basic 87 Task: 9, Basic 107 Task: 5, Basic 30 Task: 8, Basic 56 Task: 2, Basic 119 Task: 3, Basic 15 Task: 3, Basic 37 Task: 9], Basic 4 Server: [Basic 12 Task: 9, Basic 112 Task: 7, Basic 84 Task: 3, Basic 88 Task: 8, Basic 49 Task: 5], Basic 5 Server: [Basic 18 Task: 1.0]}
# Resource allocation Rewards - {Basic 0: [Basic 121], Basic 1: [], Basic 2: [], Basic 3: [Basic 107], Basic 4: [], Basic 5: [Basic 18]}
# Env Done: False
# Next State: Env State (0x1f9e7f03cc8) at time step: 13
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 30, Basic 56, Basic 119, Basic 15, Basic 37, Basic 87], Basic 4: [Basic 12, Basic 112, Basic 84, Basic 88, Basic 49], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 1, Basic 101 Task: 1], Basic 1 Server: [Basic 2 Task: 2, Basic 114 Task: 5, Basic 6 Task: 2], Basic 2 Server: [Basic 78 Task: 6, Basic 29 Task: 10, Basic 31 Task: 5, Basic 85 Task: 1], Basic 3 Server: [Basic 30 Task: 7, Basic 56 Task: 6, Basic 119 Task: 10, Basic 15 Task: 8, Basic 37 Task: 6, Basic 87 Task: 9], Basic 4 Server: [Basic 12 Task: 6, Basic 112 Task: 7, Basic 84 Task: 3, Basic 88 Task: 9, Basic 49 Task: 1], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 87], Basic 4: [Basic 12, Basic 49]}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 14
# 	Auction Task -> Basic 7 Task (0x1f9e7f1e828) - Unassigned, Storage: 78.0, Comp: 25.0, Results data: 28.0, Auction time: 14, Deadline: 23
# 	Servers -> Basic 0: [Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114, Basic 6], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 112, Basic 84, Basic 88], Basic 5: []
#
# Auction prices - {Basic 0 Server: 9, Basic 1 Server: 2, Basic 2 Server: 8, Basic 3 Server: 10, Basic 4 Server: 9, Basic 5 Server: 0}
# Auction Rewards - {Basic 1 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 14
# 	Auction Task -> Basic 14 Task (0x1f9e7f1ee58) - Unassigned, Storage: 63.0, Comp: 30.0, Results data: 24.0, Auction time: 14, Deadline: 24
# 	Servers -> Basic 0: [Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114, Basic 6, Basic 7], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 112, Basic 84, Basic 88], Basic 5: []
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 1, Basic 2 Server: 4, Basic 3 Server: 2, Basic 4 Server: 10, Basic 5 Server: 7}
# Auction Rewards - {Basic 1 Server: 1}
# Next State: Env State (0x1f9e7f03ea8) at time step: 14
# 	Auction Task -> Basic 68 Task (0x1f9e7f1fc18) - Unassigned, Storage: 64.0, Comp: 28.0, Results data: 26.0, Auction time: 14, Deadline: 24
# 	Servers -> Basic 0: [Basic 0, Basic 101], Basic 1: [Basic 2, Basic 114, Basic 6, Basic 7, Basic 14], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 112, Basic 84, Basic 88], Basic 5: []
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 3, Basic 2 Server: 10, Basic 3 Server: 2, Basic 4 Server: 10, Basic 5 Server: 0}
# Auction Rewards - {Basic 0 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 14
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 68], Basic 1: [Basic 2, Basic 114, Basic 6, Basic 7, Basic 14], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 30, Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 112, Basic 84, Basic 88], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 6, Basic 101 Task: 10, Basic 68 Task: 6], Basic 1 Server: [Basic 2 Task: 9, Basic 114 Task: 5, Basic 6 Task: 10, Basic 7 Task: 2, Basic 14 Task: 7], Basic 2 Server: [Basic 78 Task: 10, Basic 29 Task: 10, Basic 31 Task: 2, Basic 85 Task: 5], Basic 3 Server: [Basic 30 Task: 4, Basic 56 Task: 7, Basic 119 Task: 3, Basic 15 Task: 4, Basic 37 Task: 3], Basic 4 Server: [Basic 112 Task: 3, Basic 84 Task: 7, Basic 88 Task: 4], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [Basic 2], Basic 2: [], Basic 3: [Basic 30], Basic 4: [Basic 112]}
# Env Done: False
# Next State: Env State (0x1f9e7f03ea8) at time step: 15
# 	Auction Task -> Basic 51 Task (0x1f9e7f0c708) - Unassigned, Storage: 71.0, Comp: 50.0, Results data: 18.0, Auction time: 15, Deadline: 26
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 68], Basic 1: [Basic 114, Basic 6, Basic 7, Basic 14], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 84, Basic 88], Basic 5: []
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 2, Basic 2 Server: 8, Basic 3 Server: 6, Basic 4 Server: 0, Basic 5 Server: 6}
# Auction Rewards - {Basic 1 Server: 2}
# Next State: Env State (0x1f9e7f03cc8) at time step: 15
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 68], Basic 1: [Basic 114, Basic 6, Basic 7, Basic 14, Basic 51], Basic 2: [Basic 78, Basic 29, Basic 31, Basic 85], Basic 3: [Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 84, Basic 88], Basic 5: []
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 2, Basic 101 Task: 7, Basic 68 Task: 1], Basic 1 Server: [Basic 114 Task: 1, Basic 6 Task: 8, Basic 7 Task: 8, Basic 14 Task: 7, Basic 51 Task: 4], Basic 2 Server: [Basic 78 Task: 9, Basic 29 Task: 3, Basic 31 Task: 3, Basic 85 Task: 10], Basic 3 Server: [Basic 56 Task: 2, Basic 119 Task: 8, Basic 15 Task: 4, Basic 37 Task: 5], Basic 4 Server: [Basic 84 Task: 10, Basic 88 Task: 8], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: []}
# Env Done: False
# Next State: Env State (0x1f9e7ffadb8) at time step: 16
# 	Auction Task -> Basic 118 Task (0x1f9e7f213a8) - Unassigned, Storage: 63.0, Comp: 49.0, Results data: 25.0, Auction time: 16, Deadline: 23
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 68], Basic 1: [Basic 114, Basic 6, Basic 7, Basic 14, Basic 51], Basic 2: [Basic 29, Basic 31, Basic 85, Basic 78], Basic 3: [Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 84, Basic 88], Basic 5: []
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 10, Basic 2 Server: 9, Basic 3 Server: 10, Basic 4 Server: 9, Basic 5 Server: 7}
# Auction Rewards - {Basic 0 Server: 6}
# Next State: Env State (0x1f9e800df98) at time step: 16
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 0, Basic 101, Basic 68, Basic 118], Basic 1: [Basic 114, Basic 6, Basic 7, Basic 14, Basic 51], Basic 2: [Basic 29, Basic 31, Basic 85, Basic 78], Basic 3: [Basic 56, Basic 119, Basic 15, Basic 37], Basic 4: [Basic 84, Basic 88], Basic 5: []
#
# Resource allocation weights - {Basic 0 Server: [Basic 0 Task: 1, Basic 101 Task: 1, Basic 68 Task: 9, Basic 118 Task: 5], Basic 1 Server: [Basic 114 Task: 1, Basic 6 Task: 9, Basic 7 Task: 2, Basic 14 Task: 6, Basic 51 Task: 6], Basic 2 Server: [Basic 29 Task: 2, Basic 31 Task: 5, Basic 85 Task: 5, Basic 78 Task: 8], Basic 3 Server: [Basic 56 Task: 10, Basic 119 Task: 3, Basic 15 Task: 6, Basic 37 Task: 10], Basic 4 Server: [Basic 84 Task: 9, Basic 88 Task: 4], Basic 5 Server: []}
# Resource allocation Rewards - {Basic 0: [Basic 101, Basic 0], Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: []}
# Env Done: False
# Next State: Env State (0x1f9e7ffadb8) at time step: 17
# 	Auction Task -> Basic 113 Task (0x1f9e7f210d8) - Unassigned, Storage: 62.0, Comp: 52.0, Results data: 29.0, Auction time: 17, Deadline: 25
# ...
#
# Auction prices - {Basic 0 Server: 10, Basic 1 Server: 7, Basic 2 Server: 7, Basic 3 Server: 5, Basic 4 Server: 1, Basic 5 Server: 2}
# Auction Rewards - {Basic 4 Server: 1}
# Next State: Env State (0x1f9e800df98) at time step: 54
# 	Auction Task -> Basic 55 Task (0x1f9e7f0c0d8) - Unassigned, Storage: 71.0, Comp: 31.0, Results data: 12.0, Auction time: 54, Deadline: 63
# 	Servers -> Basic 0: [Basic 52, Basic 123, Basic 67, Basic 23], Basic 1: [Basic 26, Basic 44, Basic 72, Basic 22, Basic 25, Basic 50], Basic 2: [Basic 43], Basic 3: [Basic 48, Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 98, Basic 108, Basic 66, Basic 93]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 2, Basic 2 Server: 1, Basic 3 Server: 2, Basic 4 Server: 5, Basic 5 Server: 2}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e8012f98) at time step: 54
# 	Auction Task -> Basic 110 Task (0x1f9e7f19ee8) - Unassigned, Storage: 76.0, Comp: 29.0, Results data: 24.0, Auction time: 54, Deadline: 61
# 	Servers -> Basic 0: [Basic 52, Basic 123, Basic 67, Basic 23], Basic 1: [Basic 26, Basic 44, Basic 72, Basic 22, Basic 25, Basic 50], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 48, Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 98, Basic 108, Basic 66, Basic 93]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 2, Basic 2 Server: 6, Basic 3 Server: 9, Basic 4 Server: 8, Basic 5 Server: 2}
# Auction Rewards - {Basic 1 Server: 2}
# Next State: Env State (0x1f9e800df98) at time step: 54
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 52, Basic 123, Basic 67, Basic 23], Basic 1: [Basic 26, Basic 44, Basic 72, Basic 22, Basic 25, Basic 50, Basic 110], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 48, Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 98, Basic 108, Basic 66, Basic 93]
#
# Resource allocation weights - {Basic 0 Server: [Basic 52 Task: 6, Basic 123 Task: 5, Basic 67 Task: 2, Basic 23 Task: 6], Basic 1 Server: [Basic 26 Task: 9, Basic 44 Task: 2, Basic 72 Task: 3, Basic 22 Task: 7, Basic 25 Task: 8, Basic 50 Task: 1, Basic 110 Task: 10], Basic 2 Server: [Basic 43 Task: 8, Basic 55 Task: 5], Basic 3 Server: [Basic 48 Task: 2, Basic 92 Task: 1, Basic 42 Task: 9, Basic 21 Task: 1], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 9, Basic 98 Task: 4, Basic 108 Task: 9, Basic 66 Task: 1, Basic 93 Task: 7]}
# Resource allocation Rewards - {Basic 0: [Basic 123], Basic 1: [Basic 72], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e8012f98) at time step: 55
# 	Auction Task -> Basic 86 Task (0x1f9e7f1fa68) - Unassigned, Storage: 66.0, Comp: 51.0, Results data: 25.0, Auction time: 55, Deadline: 66
# 	Servers -> Basic 0: [Basic 52, Basic 67, Basic 23], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 48, Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 98, Basic 108, Basic 66, Basic 93]
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 6, Basic 2 Server: 8, Basic 3 Server: 9, Basic 4 Server: 9, Basic 5 Server: 2}
# Auction Rewards - {Basic 5 Server: 2}
# Next State: Env State (0x1f9e800df98) at time step: 55
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 52, Basic 67, Basic 23], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 48, Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 98, Basic 108, Basic 66, Basic 93, Basic 86]
#
# Resource allocation weights - {Basic 0 Server: [Basic 52 Task: 7, Basic 67 Task: 2, Basic 23 Task: 1], Basic 1 Server: [Basic 26 Task: 6, Basic 44 Task: 1, Basic 22 Task: 2, Basic 25 Task: 2, Basic 50 Task: 3, Basic 110 Task: 9], Basic 2 Server: [Basic 43 Task: 7, Basic 55 Task: 8], Basic 3 Server: [Basic 48 Task: 7, Basic 92 Task: 1, Basic 42 Task: 10, Basic 21 Task: 1], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 10, Basic 98 Task: 10, Basic 108 Task: 3, Basic 66 Task: 8, Basic 93 Task: 1, Basic 86 Task: 1]}
# Resource allocation Rewards - {Basic 0: [Basic 52, Basic 67, Basic 23], Basic 1: [], Basic 2: [], Basic 3: [Basic 48], Basic 4: [], Basic 5: [Basic 98]}
# Env Done: False
# Next State: Env State (0x1f9e8012f98) at time step: 56
# 	Auction Task -> Basic 11 Task (0x1f9e7f1e5e8) - Unassigned, Storage: 73.0, Comp: 28.0, Results data: 27.0, Auction time: 56, Deadline: 66
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 4, Basic 2 Server: 8, Basic 3 Server: 8, Basic 4 Server: 4, Basic 5 Server: 7}
# Auction Rewards - {Basic 1 Server: 4}
# Next State: Env State (0x1f9e8094f98) at time step: 56
# 	Auction Task -> Basic 36 Task (0x1f9e7f143a8) - Unassigned, Storage: 72.0, Comp: 40.0, Results data: 28.0, Auction time: 56, Deadline: 64
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11], Basic 2: [Basic 43, Basic 55], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86]
#
# Auction prices - {Basic 0 Server: 2, Basic 1 Server: 2, Basic 2 Server: 1, Basic 3 Server: 7, Basic 4 Server: 10, Basic 5 Server: 7}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e8012f98) at time step: 56
# 	Auction Task -> Basic 41 Task (0x1f9e7f14288) - Unassigned, Storage: 61.0, Comp: 52.0, Results data: 20.0, Auction time: 56, Deadline: 63
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11], Basic 2: [Basic 43, Basic 55, Basic 36], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 2, Basic 2 Server: 2, Basic 3 Server: 2, Basic 4 Server: 6, Basic 5 Server: 1}
# Auction Rewards - {Basic 5 Server: 1}
# Next State: Env State (0x1f9e8094f98) at time step: 56
# 	Auction Task -> Basic 46 Task (0x1f9e7f144c8) - Unassigned, Storage: 74.0, Comp: 30.0, Results data: 28.0, Auction time: 56, Deadline: 68
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11], Basic 2: [Basic 43, Basic 55, Basic 36], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 1, Basic 1 Server: 1, Basic 2 Server: 0, Basic 3 Server: 7, Basic 4 Server: 4, Basic 5 Server: 7}
# Auction Rewards - {Basic 1 Server: 1}
# Next State: Env State (0x1f9e8012f98) at time step: 56
# 	Auction Task -> Basic 77 Task (0x1f9e7f1fee8) - Unassigned, Storage: 58.0, Comp: 35.0, Results data: 30.0, Auction time: 56, Deadline: 64
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 43, Basic 55, Basic 36], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 6, Basic 2 Server: 1, Basic 3 Server: 2, Basic 4 Server: 7, Basic 5 Server: 9}
# Auction Rewards - {Basic 2 Server: 1}
# Next State: Env State (0x1f9e8094f98) at time step: 56
# 	Auction Task -> Basic 120 Task (0x1f9e7f214c8) - Unassigned, Storage: 56.0, Comp: 47.0, Results data: 16.0, Auction time: 56, Deadline: 65
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 43, Basic 55, Basic 36, Basic 77], Basic 3: [Basic 92, Basic 42, Basic 21], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 6, Basic 1 Server: 7, Basic 2 Server: 5, Basic 3 Server: 2, Basic 4 Server: 5, Basic 5 Server: 5}
# Auction Rewards - {Basic 3 Server: 2}
# Next State: Env State (0x1f9e8012f98) at time step: 56
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [Basic 26, Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 43, Basic 55, Basic 36, Basic 77], Basic 3: [Basic 92, Basic 42, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [Basic 26 Task: 9, Basic 44 Task: 6, Basic 22 Task: 1, Basic 25 Task: 1, Basic 50 Task: 2, Basic 110 Task: 2, Basic 11 Task: 3, Basic 46 Task: 5], Basic 2 Server: [Basic 43 Task: 1, Basic 55 Task: 1, Basic 36 Task: 6, Basic 77 Task: 1], Basic 3 Server: [Basic 92 Task: 1, Basic 42 Task: 3, Basic 21 Task: 10, Basic 120 Task: 3], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 10, Basic 108 Task: 3, Basic 66 Task: 8, Basic 93 Task: 6, Basic 86 Task: 1, Basic 41 Task: 8]}
# Resource allocation Rewards - {Basic 1: [Basic 26], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e8094f98) at time step: 57
# 	Auction Task -> Basic 27 Task (0x1f9e7f12168) - Unassigned, Storage: 78.0, Comp: 60.0, Results data: 11.0, Auction time: 57, Deadline: 67
# 	Servers -> Basic 0: [], Basic 1: [Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 43], Basic 3: [Basic 92, Basic 42, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 8, Basic 1 Server: 8, Basic 2 Server: 2, Basic 3 Server: 2, Basic 4 Server: 9, Basic 5 Server: 5}
# Auction Rewards - {Basic 2 Server: 2}
# Next State: Env State (0x1f9e8012f98) at time step: 57
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 43, Basic 27], Basic 3: [Basic 92, Basic 42, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [Basic 44 Task: 9, Basic 22 Task: 9, Basic 25 Task: 1, Basic 50 Task: 9, Basic 110 Task: 3, Basic 11 Task: 10, Basic 46 Task: 10], Basic 2 Server: [Basic 55 Task: 10, Basic 36 Task: 6, Basic 77 Task: 2, Basic 43 Task: 10, Basic 27 Task: 8], Basic 3 Server: [Basic 92 Task: 1, Basic 42 Task: 2, Basic 21 Task: 2, Basic 120 Task: 7], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 9, Basic 108 Task: 5, Basic 66 Task: 9, Basic 93 Task: 4, Basic 86 Task: 3, Basic 41 Task: 8]}
# Resource allocation Rewards - {Basic 1: [], Basic 2: [], Basic 3: [], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e8094f98) at time step: 58
# 	Auction Task -> Basic 74 Task (0x1f9e7f1fe58) - Unassigned, Storage: 62.0, Comp: 52.0, Results data: 24.0, Auction time: 58, Deadline: 64
# 	Servers -> Basic 0: [], Basic 1: [Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 43], Basic 3: [Basic 92, Basic 42, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 7, Basic 1 Server: 4, Basic 2 Server: 2, Basic 3 Server: 2, Basic 4 Server: 3, Basic 5 Server: 6}
# Auction Rewards - {Basic 2 Server: 2}
# Next State: Env State (0x1f9e8012f98) at time step: 58
# 	Auction Task -> None
# 	Servers -> Basic 0: [], Basic 1: [Basic 44, Basic 22, Basic 25, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 43, Basic 74], Basic 3: [Basic 92, Basic 42, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Resource allocation weights - {Basic 0 Server: [], Basic 1 Server: [Basic 44 Task: 10, Basic 22 Task: 4, Basic 25 Task: 4, Basic 50 Task: 2, Basic 110 Task: 4, Basic 11 Task: 1, Basic 46 Task: 2], Basic 2 Server: [Basic 55 Task: 8, Basic 36 Task: 4, Basic 77 Task: 6, Basic 27 Task: 8, Basic 43 Task: 10, Basic 74 Task: 1], Basic 3 Server: [Basic 92 Task: 7, Basic 42 Task: 1, Basic 21 Task: 2, Basic 120 Task: 10], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 3, Basic 108 Task: 9, Basic 66 Task: 4, Basic 93 Task: 9, Basic 86 Task: 5, Basic 41 Task: 7]}
# Resource allocation Rewards - {Basic 1: [Basic 25], Basic 2: [], Basic 3: [Basic 42], Basic 4: [], Basic 5: []}
# Env Done: False
# Next State: Env State (0x1f9e8094f98) at time step: 59
# 	Auction Task -> Basic 102 Task (0x1f9e7f19a68) - Unassigned, Storage: 53.0, Comp: 36.0, Results data: 26.0, Auction time: 59, Deadline: 70
# 	Servers -> Basic 0: [], Basic 1: [Basic 44, Basic 22, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 74, Basic 43], Basic 3: [Basic 92, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Auction prices - {Basic 0 Server: 4, Basic 1 Server: 5, Basic 2 Server: 7, Basic 3 Server: 9, Basic 4 Server: 0, Basic 5 Server: 0}
# Auction Rewards - {Basic 0 Server: 4}
# Next State: Env State (0x1f9e8012f98) at time step: 59
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 102], Basic 1: [Basic 44, Basic 22, Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 74, Basic 43], Basic 3: [Basic 92, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 81, Basic 108, Basic 66, Basic 93, Basic 86, Basic 41]
#
# Resource allocation weights - {Basic 0 Server: [Basic 102 Task: 1.0], Basic 1 Server: [Basic 44 Task: 4, Basic 22 Task: 7, Basic 50 Task: 6, Basic 110 Task: 1, Basic 11 Task: 7, Basic 46 Task: 10], Basic 2 Server: [Basic 55 Task: 4, Basic 36 Task: 4, Basic 77 Task: 9, Basic 27 Task: 9, Basic 74 Task: 4, Basic 43 Task: 10], Basic 3 Server: [Basic 92 Task: 1, Basic 21 Task: 1, Basic 120 Task: 2], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 81 Task: 10, Basic 108 Task: 7, Basic 66 Task: 6, Basic 93 Task: 7, Basic 86 Task: 5, Basic 41 Task: 6]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [Basic 44, Basic 22], Basic 2: [Basic 43], Basic 3: [], Basic 4: [], Basic 5: [Basic 81, Basic 66]}
# Env Done: False
# Next State: Env State (0x1f9e8094f98) at time step: 60
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 102], Basic 1: [Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 74], Basic 3: [Basic 92, Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 108, Basic 93, Basic 86, Basic 41]
#
# Resource allocation weights - {Basic 0 Server: [Basic 102 Task: 1.0], Basic 1 Server: [Basic 50 Task: 3, Basic 110 Task: 6, Basic 11 Task: 2, Basic 46 Task: 9], Basic 2 Server: [Basic 55 Task: 10, Basic 36 Task: 4, Basic 77 Task: 6, Basic 27 Task: 5, Basic 74 Task: 6], Basic 3 Server: [Basic 92 Task: 10, Basic 21 Task: 9, Basic 120 Task: 9], Basic 4 Server: [Basic 34 Task: 1.0], Basic 5 Server: [Basic 108 Task: 10, Basic 93 Task: 9, Basic 86 Task: 10, Basic 41 Task: 7]}
# Resource allocation Rewards - {Basic 0: [], Basic 1: [], Basic 2: [], Basic 3: [Basic 92], Basic 4: [], Basic 5: []}
# Env Done: True
# Next State: Env State (0x1f9e8012f98) at time step: 61
# 	Auction Task -> None
# 	Servers -> Basic 0: [Basic 102], Basic 1: [Basic 50, Basic 110, Basic 11, Basic 46], Basic 2: [Basic 55, Basic 36, Basic 77, Basic 27, Basic 74], Basic 3: [Basic 21, Basic 120], Basic 4: [Basic 34], Basic 5: [Basic 108, Basic 93, Basic 86, Basic 41]
#
# Total Price: -177.0, Num Completed Task: 13, Num Failed Tasks: 94

# %%
# Every 3 episodes, the agents are trained
if episode % 3 == 0:
    for task_pricing_agent in _server_task_pricing_agents.values():
        task_pricing_agent.train()
    for resource_weighting_agent in _server_resource_allocation_agents.values():
        resource_weighting_agent.train()

# %%
agent = _task_pricing_agents[0]

network_variables = agent.network_model.trainable_variables
with tf.GradientTape() as tape:
    tape.watch(network_variables)

    model_val = np.zeros((agent.minibatch_size, agent.num_outputs))
    target_val = np.zeros((agent.minibatch_size, agent.num_outputs))

    minibatch = rnd.sample(agent.replay_buffer, agent.minibatch_size)
    for pos, trajectory in enumerate(minibatch):
        observation, action, reward, next_observation = trajectory

        model_val[pos] = np.array(agent.network_model(observation))
        target_val[pos] = np.array(agent.network_model(observation))

        if next_observation is not None:
            max_next_value = np.max(agent.network_target(next_observation))
            model_val[pos][action] = reward + agent.discount_factor * max_next_value
        else:
            model_val[pos][action] = reward

        error = tf.square(target_val - model_val)
        error = tf.reduce_mean(0.5 * error)

print(f'agent with error {error}')
network_gradients = tape.gradient(error, network_variables)
print(f'Network gradients are {network_gradients}')
# self.optimiser.apply_gradients(zip(network_gradients, network_variables))
# Out:
# agent with error 0.04607089559463275
# Network gradients are [None, None, None, None, None, None, None, None, None, None]

# %%
agent = _task_pricing_agents[0]

network_variables = agent.network_model.trainable_variables

minibatch = rnd.sample(agent.replay_buffer, agent.minibatch_size)
obs = np.array([traj[0] for traj in minibatch])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-53cf11813b49> in <module>
#       4
#       5 minibatch = rnd.sample(agent.replay_buffer, agent.minibatch_size)
# ----> 6 obs = np.array([traj[0] for traj in minibatch])
#
# ValueError: could not broadcast input array from shape (2,9) into shape (1)

# %%
# Every 15 episodes, the agents are evaluated
if episode % 15 == 0:
    eval_env(_training_envs, _task_pricing_agents, _resource_weighting_agents)
